# %% [markdown]
# # Plot dose depth dose and uncertainty
#
# Use the output of the following simulation:
# - Folder: dosimetry/
# - Macros: ex1.mac

# %%
# Tell Jupyter to plot figure right in the page
# %matplotlib widget

# Module with plot capabilities
import matplotlib.pyplot as plt

# Module with scientific computing functions (matrix/vector)
import numpy as np                

# Modules with reading/write folder/file functions
import os
from pathlib import Path

# %%
# The following command display the current working directory (where jupyter has been launched)
cwd = os.getcwd()
print('The Current Working Directory (CWD) is: \n', cwd)
# Out:
# The Current Working Directory (CWD) is:
#  /home/vgate/WORK/geant4course/SSFM/GATE_exercises/2_dosimetry

# %%
# Display the content of a folder
output_folder = Path('./output')                            # <--------------------------------------TO CHANGE BY YOUR OWN OUTPUT FOLDER 
if (not output_folder.is_dir()):
    print('ERROR: {} is not a folder.'.format(output_folder))
else:
    print('The folder and contains the following files:'.format(output_folder))
    p = output_folder.glob('**/*')
    files = [x for x in p if x.is_file()]
    for x in files:
        print(x)
# Out:
# The folder and contains the following files:
# output/gamma-depth-Dose-Squared.txt
# output/depth-pat-Edep-Squared.txt
# output/depth-pat-Dose.txt
# output/gamma-profile-Edep-Uncertainty.raw
# output/3d-pat-proton-Edep.raw
# output/gamma-profile-Edep.raw
# output/3d-pat-Dose-norm.mhd
# output/3d-pat-Dose-Squared.mhd
# output/3d-pat-Dose-Uncertainty.mhd
# output/3d-pat-proton-Edep-Uncertainty.mhd
# output/.gitkeep
# output/stat-pat-proton.txt
# output/3d-pat-Dose-Uncertainty.raw
# output/gamma-profile-Dose-Squared.mhd
# output/3d-pat-Dose.raw
# output/gamma-profile-Edep.txt
# output/gamma-profile-Edep-Uncertainty.mhd
# output/gamma-depth-Dose-Uncertainty.txt
# output/gamma-profile-NbOfHits.raw
# output/profile-pat-Edep.txt
# output/profile-pat-Dose.txt
# output/gamma-profile-NbOfHits.txt
# output/3d-pat-proton-Dose-norm.mhd
# output/gamma-profile-Dose.raw
# output/gamma-profile-Edep-Squared.raw
# output/gamma-depth-Edep-Squared.txt
# output/gamma-depth2-Edep-Uncertainty.root
# output/profile-pat-Edep-Squared.txt
# output/gamma-profile-Dose-Uncertainty.raw
# output/3d-pat-proton-Edep-Squared.raw
# output/profile-pat-proton-Dose.txt
# output/3d-pat-proton-Edep-Squared.mhd
# output/gamma-depth-Edep.mhd
# output/gamma-profile-Dose-Uncertainty.mhd
# output/depth-pat-proton-Edep.txt
# output/gamma-depth-NbOfHits.txt
# output/3d-pat-proton-Edep.mhd
# output/profile-pat-proton-Edep.txt
# output/gamma-profile-Edep-Squared.mhd
# output/gamma-profile-Dose-Squared.raw
# output/3d-pat-proton-Dose.mhd
# output/profile-pat-proton-Edep-Uncertainty.txt
# output/ex1_pynb.pdf
# output/gamma-stat.txt
# output/3d-pat-Edep-Uncertainty.mhd
# output/3d-pat-proton-Dose.raw
# output/gamma-depth-Edep-Uncertainty.raw
# output/gamma-profile-Edep-Uncertainty.txt
# output/gamma-depth-Edep.txt
# output/gamma-depth-Dose-Squared.raw
# output/3d-pat-Dose-Squared.raw
# output/gamma-depth-Edep-Uncertainty.txt
# output/gamma-depth2-Edep.root
# output/gamma-depth-Edep.raw
# output/gamma-depth-NbOfHits.raw
# output/depth-pat-Edep.txt
# output/3d-pat-proton-Dose-Squared.raw
# output/gamma-depth2-Dose-Squared.root
# output/profile-pat-Edep-Uncertainty.txt
# output/gamma-profile-NbOfHits.mhd
# output/3d-pat-Edep.raw
# output/profile-pat-proton-Edep-Squared.txt
# output/gamma-profile-Dose.mhd
# output/gamma-depth-Dose.raw
# output/3d-pat-proton-Dose-Squared.mhd
# output/3d-pat-Edep-Squared.mhd
# output/gamma-depth-Edep-Uncertainty.mhd
# output/3d-pat-proton-Dose-Uncertainty.mhd
# output/stat-pat.txt
# output/gamma-profile-Dose.txt
# output/gamma-depth-Dose.mhd
# output/gamma-depth2-Edep-Squared.root
# output/gamma-profile-Edep-Squared.txt
# output/gamma-depth-NbOfHits.mhd
# output/gamma-depth-Dose-Squared.mhd
# output/3d-pat-proton-Dose-Uncertainty.raw
# output/3d-pat-Edep.mhd
# output/depth-pat-proton-Dose.txt
# output/gamma-depth-Edep-Squared.raw
# output/gamma-profile-Dose-Squared.txt
# output/3d-pat-NbOfHits.mhd
# output/3d-pat-Edep-Squared.raw
# output/gamma-depth-Dose.txt
# output/depth-pat-Edep-Uncertainty.txt
# output/3d-pat-Edep-Uncertainty.raw
# output/gamma-depth2-Dose-Uncertainty.root
# output/depth-pat-proton-Edep-Uncertainty.txt
# output/depth-pat-proton-Edep-Squared.txt
# output/3d-pat-NbOfHits.raw
# output/3d-pat-Dose.mhd
# output/gamma-profile-Edep.mhd
# output/gamma-depth2-NbOfHits.root
# output/gamma-depth-Dose-Uncertainty.mhd
# output/gamma-depth-Edep-Squared.mhd
# output/gamma-depth-Dose-Uncertainty.raw
# output/gamma-profile-Dose-Uncertainty.txt
# output/3d-pat-proton-Dose-norm.raw
# output/gamma-depth2-Dose.root
# output/3d-pat-Dose-norm.raw
# output/3d-pat-proton-Edep-Uncertainty.raw

# %%
# Set the filenames (d = depth, p = profile)
f_d_edep = os.path.join(output_folder, 'gamma-depth-Edep.txt')
f_d_uncert = os.path.join(output_folder, 'gamma-depth-Edep-Uncertainty.txt')
f_p_edep = os.path.join(output_folder, 'gamma-profile-Edep.txt')
f_p_uncert = os.path.join(output_folder, 'gamma-profile-Edep-Uncertainty.txt')

# %%
# Load data from txt files
d_edep = np.loadtxt(f_d_edep)
d_uncert = np.loadtxt(f_d_uncert)
p_edep = np.loadtxt(f_p_edep)
p_uncert = np.loadtxt(f_p_uncert)

# %%
# Declare a single figure (one row, one column)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12, 6))

# X values from 0 to n, n is the length of d_edep
n = len(d_edep)
x = np.linspace(0, n, n)

# convert x in mm, it should be 40cm / 100 (in the macro)
# if you change the values in the macro, modify the conversion to mm here.
x = x*400/100

y = d_edep
c1 = ax.plot(x, y, 'r-', label='edep', linewidth=2)

# Second curve, gamma uncertainty in blue, share the same x axis, but use a
# different y axis
y = d_uncert
ax2 = ax.twinx()
c2 = ax2.plot(x, y, 'b-', label='$\sigma$ (uncertainty)')

# Add the legend and the title
lns = c1+c2
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc=0)
ax.set_title('Depth deposited energy')
ax.set_xlabel('Distance in mm')
ax.set_ylabel('Deposited energy in MeV')
f = ax2.set_ylabel('Uncertainty')

# save on disk (optional)
plt.savefig('depth_dose.png',dpi=300,bbox_inches="tight",pad_inches=None)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Declare a figure 
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12, 6))

# Third curve, gamma profile in green
n = len(p_edep)
x = np.linspace(0, n, n)

# convert x in mm, it should be 4cm / 100 (in the macro)
# if you change the values in the macro, modify the conversion to mm here.
x = x*40/100

y = p_edep
c3 = ax.plot(x, y, 'r-', label='edep', linewidth=2)

# Last curve, gamma uncertainty profile
y = p_uncert
ax2 = ax.twinx()
c4 = ax2.plot(x, y, 'b-', label='$\sigma$ (uncertainty)')

# Add the legend and the title
lns = c3+c4
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc=0)
ax.set_title('Deposited energy profile')
ax.set_xlabel('Distance in mm')
ax.set_ylabel('Deposited energy in MeV')
f = ax2.set_ylabel('Uncertainty')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Declare a single figure (one row, one column)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12, 6))

# X values from 0 to n, n is the length of d_edep
n = len(d_edep)
x = np.linspace(0, n, n)

# convert x in mm, it should be 40cm / 100 (in the macro)
# if you change the values in the macro, modify the conversion to mm here.
x = x*400/100

y = d_uncert/d_edep
c1 = ax.plot(x, y, 'm-', label='uncertainty edep/edep', linewidth=2)

# Add the legend and the title
lns = c1
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc=0)
ax.set_title('Depth deposited energy')
ax.set_xlabel('Distance in mm')
ax.set_ylabel('relative deposited energy in MeV')
f = ax2.set_ylabel('Relative Uncertainty')

# save on disk (optional)
plt.savefig('depth_dose_relativeUncertainty.png',dpi=300,bbox_inches="tight",pad_inches=None)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Declare a figure 
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12, 6))

# Third curve, gamma profile in green
n = len(p_edep)
x = np.linspace(0, n, n)

# convert x in mm, it should be 4cm / 100 (in the macro)
# if you change the values in the macro, modify the conversion to mm here.
x = x*40/100

y = p_uncert/p_edep
c3 = ax.plot(x, y, 'aquamarine', label='edep', linewidth=2, linestyle='dashed')

# Add the legend and the title
lns = c3
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc=0)
ax.set_title('realtive uncertainty deposited energy profile')
ax.set_xlabel('Distance in mm')
ax.set_ylabel('Relative uncertainty deposited energy in MeV')
f = ax2.set_ylabel('Relative Uncertainty')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
